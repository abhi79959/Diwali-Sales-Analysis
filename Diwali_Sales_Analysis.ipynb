# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Diwali Sales.csv', encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (11253, 15)

# %%
df.head()
# Out:
#      User_ID  Cust_name Product_ID Gender Age Group   Age  Marital_Status  \
# 0  1002903.0  Sanskriti  P00125942      F     26-35  28.0             0.0
# 1  1000732.0     Kartik  P00110942      F     26-35  35.0             1.0
# 2  1001990.0      Bindu  P00118542      F     26-35  35.0             1.0
# 3  1001425.0     Sudevi  P00237842      M      0-17  16.0             0.0
# 4  1000588.0       Joni  P00057942      M     26-35  28.0             1.0
#
#            State      Zone     Occupation Product_Category  Orders   Amount  \
# 0    Maharashtra         x     Healthcare   Woodenportrait     1.0  23952.0
# 1         Andhra  Southern           Govt   Woodenportrait     3.0  23934.0
# 2  Uttar Pradesh   Central  Communication   Woodenportrait     3.0  23924.0
# 3      Karnataka  Southern   Construction   Woodenportrait     2.0  23912.0
# 4        Gujarat   Western        Banking   Woodenportrait     2.0  23877.0
#
#    Status unnamed1
# 0     NaN      NaN
# 1     NaN      NaN
# 2     NaN      NaN
# 3     NaN      NaN
# 4     NaN      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11253 entries, 0 to 11252
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11252 non-null  float64
#  1   Cust_name         11252 non-null  object
#  2   Product_ID        11252 non-null  object
#  3   Gender            11252 non-null  object
#  4   Age Group         11252 non-null  object
#  5   Age               11252 non-null  float64
#  6   Marital_Status    11252 non-null  float64
#  7   State             11252 non-null  object
#  8   Zone              11252 non-null  object
#  9   Occupation        11252 non-null  object
#  10  Product_Category  11253 non-null  object
#  11  Orders            11252 non-null  float64
#  12  Amount            11240 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          1 non-null      object
# dtypes: float64(6), object(9)
# memory usage: 1.3+ MB

# %%
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns= {'Marital_Status':'Shaadi'})
# Out:
#          User_ID    Cust_name Product_ID Gender Age Group   Age  Shaadi  \
# 0      1002903.0    Sanskriti  P00125942      F     26-35  28.0     0.0
# 1      1000732.0       Kartik  P00110942      F     26-35  35.0     1.0
# 2      1001990.0        Bindu  P00118542      F     26-35  35.0     1.0
# 3      1001425.0       Sudevi  P00237842      M      0-17  16.0     0.0
# 4      1000588.0         Joni  P00057942      M     26-35  28.0     1.0
# ...          ...          ...        ...    ...       ...   ...     ...
# 11247  1000695.0      Manning  P00296942      M     18-25  19.0     1.0
# 11248  1004089.0  Reichenbach  P00171342      M     26-35  33.0     0.0
# 11249  1001209.0        Oshin  P00201342      F     36-45  40.0     0.0
# 11250  1004023.0       Noonan  P00059442      M     36-45  37.0     0.0
# 11251  1002744.0      Brumley  P00281742      F     18-25  19.0     0.0
#
#                 State      Zone     Occupation   Product_Category  Orders  \
# 0         Maharashtra         x     Healthcare     Woodenportrait     1.0
# 1              Andhra  Southern           Govt     Woodenportrait     3.0
# 2       Uttar Pradesh   Central  Communication     Woodenportrait     3.0
# 3           Karnataka  Southern   Construction     Woodenportrait     2.0
# 4             Gujarat   Western        Banking     Woodenportrait     2.0
# ...               ...       ...            ...                ...     ...
# 11247     Maharashtra   Western       Chemical  Illustrated frame     4.0
# 11248         Haryana  Northern     Healthcare  Illustrated frame     3.0
# 11249  Madhya Pradesh   Central        Textile     Vectorportrait     4.0
# 11250       Karnataka  Southern    Agriculture  Illustrated frame     3.0
# 11251     Maharashtra   Western     Healthcare  Illustrated frame     3.0
#
#        Amount
# 0       23952
# 1       23934
# 2       23924
# 3       23912
# 4       23877
# ...       ...
# 11247     370
# 11248     367
# 11249     213
# 11250     206
# 11251     188
#
# [11240 rows x 13 columns]

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders         Amount
# count  1.124000e+04  11240.000000    11240.000000  11240.000000   11240.000000
# mean   1.003004e+06     35.410320        0.420107      2.490036    9475.454893
# std    1.715973e+03     12.753299        0.493598      1.115729    5712.619044
# min    1.000001e+06     12.000000        0.000000      1.000000     188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000    5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000    8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000   12677.250000
# max    1.006040e+06     92.000000        1.000000      7.000000  254984.000000

# %%
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders         Amount
# count  11240.000000  11240.000000   11240.000000
# mean      35.410320      2.490036    9475.454893
# std       12.753299      1.115729    5712.619044
# min       12.000000      1.000000     188.000000
# 25%       27.000000      2.000000    5443.000000
# 50%       33.000000      2.000000    8109.000000
# 75%       43.000000      3.000000   12677.250000
# max       92.000000      7.000000  254984.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Gender

# %%
ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Gender',y= 'Amount' ,data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [markdown]
# ### Age

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are of age group between 26-35 yrs female*

# %% [markdown]
# ### State

# %%
# total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(5)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# total amount/sales from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively*

# %% [markdown]
# ### Marital Status

# %%
ax = sns.countplot(data = df, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are married (women) and they have high purchasing power*

# %% [markdown]
# ### Occupation

# %%
sns.set(rc={'figure.figsize':(25,5)})
ax = sns.countplot(data = df, x = 'Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector*

# %% [markdown]
# ### Product Category

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category*

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(18)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# ## Conclusion:
#
# ###

# %% [markdown]
# *Married women age group 26-35 yrs from UP,  Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Woodenportrait, LED portrait and vectorportrait category*

# %% [markdown]
# Thank you!
